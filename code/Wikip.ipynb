# %%
from pathlib import Path
import os
import pandas as pd

# %% [markdown]
# Opgaven baserer sig på data, der er webscraped. Data stammer fra Wikipedia.
#
# Der findes mange relevante pythonbiblioteker: https://pypi.org/search/?q=wikipedia

# %% [markdown]
# # wikipedia-histories 1.1.
#
# A Python tool to pull the complete edit history of a Wikipedia page.

# %%
#! pip install wikipedia-histories

# %%
import wikipedia_histories

# %%
help(wikipedia_histories)
# Out:
# Help on package wikipedia_histories:
#
# NAME
#     wikipedia_histories
#
# PACKAGE CONTENTS
#     get_histories
#     networks (package)
#     retrieve_metadata
#     revision
#
# FILE
#     c:\users\lakj\appdata\local\anaconda3\lib\site-packages\wikipedia_histories\__init__.py

# %%
# Generate a list of revisions for a specified page
mao_zedong = wikipedia_histories.get_history('Mao Zedong')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Generate a list of revisions for a specified page
# ----> 2 mao_zedong = wikipedia_histories.get_history('Mao Zedong')
#
# File ~\AppData\Local\anaconda3\lib\site-packages\wikipedia_histories\get_histories.py:210, in get_history(title, include_text, domain)
#     208 if include_text:
#     209     lang_code = extract_lang_code_from_domain(domain)
# --> 210     texts = asyncio.run(get_texts(revids, lang_code))
#     211 else:
#     212     texts = [""] * len(metadata)
#
# File ~\AppData\Local\anaconda3\lib\asyncio\runners.py:33, in run(main, debug)
#       9 """Execute the coroutine and return the result.
#      10
#      11 This function runs the passed coroutine, taking care of
#    (...)
#      30     asyncio.run(main())
#      31 """
#      32 if events._get_running_loop() is not None:
# ...

# %%
mao_zedong

# %%
input_dir = Path.cwd() / '../datasets'

# %%
files = os.listdir(input_dir)

# %%
df = pd.read_csv(input_dir / 'data_cleaned.csv')
df
# Out:
#       Unnamed: 0.1  Unnamed: 0  \
# 0                0        8884
# 1                1        8532
# 2                2         324
# 3                3        4541
# 4                4        4636
# ...            ...         ...
# 9655          9655        6334
# 9656          9656        4362
# 9657          9657        2575
# 9658          9658        7559
# 9659          9659         882
#
#                                                    App       Category  Rating  \
# 0                 "i DT" Fútbol. Todos Somos Técnicos.         SPORTS     NaN
# 1                        +Download 4 Instagram Twitter         SOCIAL     4.5
# 2                           - Free Comics - Comic Apps         COMICS     3.5
# 3                                                   .R          TOOLS     4.5
# 4                                               /u/app  COMMUNICATION     4.7
# ...                                                ...            ...     ...
# ...

# %%
import pandas as pd

# Provide the URL of the webpage containing HTML tables
url = 'https://en.wikipedia.org/w/index.php?title=Mao_Zedong&action=history'

# Use pandas to read HTML tables from the webpage
tables = pd.read_html(url, flavor='lxml')

# Now, tables is a list of DataFrame objects, each representing an HTML table
# You can access individual tables by indexing the list
for idx, table in enumerate(tables):
    print(f"Table {idx + 1}:\n{table}\n")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-3b9afbd99aa6> in <module>
#       5
#       6 # Use pandas to read HTML tables from the webpage
# ----> 7 tables = pd.read_html(url, flavor='lxml')
#       8
#       9 # Now, tables is a list of DataFrame objects, each representing an HTML table
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1083     io = stringify_path(io)
#    1084
# ...

# %% [markdown]
# ### Meget vigtige opdateringer
