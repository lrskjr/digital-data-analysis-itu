# %% [markdown]
# # Exam details
# Written work:
#
# You will have to analyze a dataset and test a relevant hypothesis.
#
# You should choose your own dataset by Lecture 12 (written hand-in already available)
#
# The report will be written as a Jupiter notebook.
#
# Minimal set of analysis:
# 1) Describe your data and visualize some key dimensions.
# 2) Perform at least two analysis (depending on what is appropriate given the data you selected):
# - Does your data contain quantitative values that allow for a hypothesis testing?
#    IF YES: Formulate an hypothesis and test it. Complement the testing with an appropriate visualization.
# - Does your data contain unstructured textual information?
#  IF YES: Perform sentiment analysis on your data and describe and visualize the results.
# - Does your data contain network structures (or a network structure can be extracted)?
#  IF YES: Ask a question about the network structure and answer it.
#
# OBS: Different datasets can be investigated in many different ways. Any combination of the above-described analysis is acceptable as long as you ask 2 questions.
# e.g. Statistical hypothesis testing + network analysis, Sentiment analysis + network analysis , Statistical hypothesis testing + Statistical hypothesis testing.
#
# Groups:  Find your own group (2 ppls - 3 is possible) let the TAs know before Fall break.
#
# Where to find the data:
# The internet is full of data, these are just few starting points:
# Data (digst.dk) - Danish Open Data
# GHO | By theme (who.int) - WHO Open Data
# DataHub  - Many datasets
# Data.gov Home - Data.gov - US Open Data
# Kaggle - All sort of datasets
# Dataset Search (google.com)
# TLC Trip Record Data - TLC (nyc.gov) - TAXI data in NYC
# Industry data and insights | BFI - Movies!
# CDE (cjis.gov) - Crime data from FBI
# Københavns Kommune (opendata.dk) - Open Data from CPH

# %% [markdown]
# Opgaven skal indeholde en eller flere af følgende:
# - Hypothesis testing
# - Sentiment Analyse
# - Network Analysis
#
# Desuden også
# - Interactive Visualization

# %% [markdown]
# # Data
# Datasættet stammer fra "The Danish Parliament Corpus 2009 - 2017, v2, w. subject annotation".
#
# Kilde:
# Hansen, Dorte Haltrup and Navarretta, Costanza, 2021, The Danish Parliament Corpus 2009 - 2017, v2, w. subject annotation, CLARIN-DK-UCPH Centre Repository, http://hdl.handle.net/20.500.12115/44.
#
#
# Datasættet består af transkriptioner af taler i Folketinget fra første samling 2009 til og med først samling 2016 (6/10 2009 – 7/9 2017). Til hver tale er der tilknyttet metadata, dels om medlemmet af folketinget ('Name', 'Gender', 'Party', 'Role', 'Title', 'Birth', 'Age'), dels om talen (Date', 'samling', 'Start time', 'End time', 'Time', 'Agenda item', 'Case no', 'Case type', 'Agenda title', 'Subject 1', 'Subject 2').
#
# Datasættet er struktureret i tsv txt-filer, som er formateret i utf-8. Der er en fil per møde.
#
# Kilde:
# Samme, Readme
#
#
# Til denne opgave har vi samlet tsv filerne i et nyt datasæt, som vi har gemt i en csv fil separeret med pipes. Csv filen er uploadet til sciencedata.dk, hvorfra den kan downloades via url med pandas.read_csv() metoden.
#
#
#
#
#
# # Emnet
# Emnet er indvandredebatten 2009 - 2017
#
# 1. de vigtigste emner over tid - hvordan er indvandredebatten afspejlet der i?
# 2. nøgleord som bliver aktualiseret i debatterne om indvandre. 2.1. Tf-Idf i relation til at identificere nøgleord. 2.2.Tf til at observere nøgleords bevægelse over tid.
# 3. sentiment analyse på taler som indeholder noget om flygtning. Det kan f.eks. være taler, som handler om 'os' og 'dem' - nærlæsning. Bliver der større variation i sentiment-scorrerne mere varieret op til et valg? Bliver de mere varieret omkring 2015?
# 4. pos -tag f.eks. verber fra forskellige partier, og hvilke adjektiver knytters sig til et begreb.

# %% [markdown]
# # Load data
#
# Data ligger på sciencedata.dk og deles derfra med download link.

# %%
import pandas as pd

# %%
df = pd.read_csv('https://sciencedata.dk/shared/825e999a5c13fd22d28d4289fa899ba1?download', sep='|')
print (f'The coloumns are {df.columns}')
# Out:
# The coloumns are Index(['ID', 'Date', 'samling', 'Start time', 'End time', 'Time',
#        'Agenda item', 'Case no', 'Case type', 'Agenda title', 'Subject 1',
#        'Subject 2', 'Name', 'Gender', 'Party', 'Role', 'Title', 'Birth', 'Age',
#        'Text'],
#       dtype='object')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

def top_distinctive_words(documents):
    
    with open('dk.txt', 'r', encoding='utf-8-sig') as f:
        stop_words = f.read().split('\n')
    
    # Create a TF-IDF vectorizer
    tfidf_vectorizer = TfidfVectorizer(max_features=10000, stop_words=stop_words)

    # Fit and transform the input documents
    tfidf_matrix = tfidf_vectorizer.fit_transform(documents)

    # Get the feature names (words)
    feature_names = tfidf_vectorizer.get_feature_names_out()

    # Initialize a list to store the top distinctive words for each document
    top_words_list = []

    # Iterate through the TF-IDF matrices for each document
    for tfidf_vector in tfidf_matrix.toarray():
        # Create a list of tuples (word, TF-IDF score) for the current document
        word_tfidf_tuples = [(feature, tfidf_score) for feature, tfidf_score in zip(feature_names, tfidf_vector) if tfidf_score > 0]

        # Sort the tuples by TF-IDF score in descending order
        word_tfidf_tuples.sort(key=lambda x: x[1], reverse=True)

        # Select the top five words with the highest TF-IDF scores
        top_words = [word for word, _ in word_tfidf_tuples[:5]]

        top_words_list.append(top_words)

    return top_words_list

# %% [markdown]
# {'analysis': 0.20851441405707477, 'calculation': 0.20851441405707477, 'for': 0.20851441405707477, 'idf': 0.41702882811414954, 'important': 0.20851441405707477, 'in': 0.20851441405707477, 'is': 0.41702882811414954, 'sample': 0.20851441405707477, 'text': 0.41702882811414954, 'tf': 0.41702882811414954, 'this': 0.20851441405707477}

# %% [markdown]
# # Feature engineering

# %%
import pandas as pd
import re
import nltk
import spacy
from collections import defaultdict
import string

# Type token ratio
def calculate_ttr(text):
    # Tranform to lower text case  
    text = text.lower()
    
    # Tokenize the input text into words
    words = re.findall(r'\b\S+\b', text)

    # Calculate the total number of tokens (words)
    total_tokens = len(words)

    # Calculate the number of unique types (unique words)
    unique_types = len(set(words))

    # Calculate the TTR (Type-Token Ratio)
    ttr = unique_types / total_tokens

    return ttr

def calculate_average_sentence_length(text):
    # Tokenize the input text into sentences
    sentences = nltk.sent_tokenize(text)

    # Calculate the total number of sentences
    total_sentences = len(sentences)

    # Calculate the total number of words in all sentences
    total_words = sum(len(nltk.word_tokenize(sentence)) for sentence in sentences)

    # Calculate the average sentence length
    if total_sentences > 0:
        average_length = total_words / total_sentences
    else:
        average_length = 0  # To avoid division by zero if there are no sentences

    return average_length


def get_pos_tags(text):
    # Load the spaCy model
    nlp = spacy.load('da_core_news_sm')

    # Process the text with spaCy
    doc = nlp(text)

    # Extract tokens and their POS tags
    pos_tags = [(token.text, token.pos_) for token in doc]

    return pos_tags

def get_pos_tag_counts(text):
    # Load the spaCy model
    nlp = spacy.load('da_core_news_sm')

    # Process the text with spaCy
    doc = nlp(text)

    # Initialize a dictionary to store POS tag counts
    pos_tag_counts = defaultdict(int)

    # Extract and count POS tags
    for token in doc:
        pos_tag_counts[token.pos_] += 1

    return dict(pos_tag_counts)


def create_bag_of_words(text):
    # Initialize a dictionary to store the bag of words
    bag_of_words = defaultdict(int)

    # Remove punctuation and convert text to lowercase
    translator = str.maketrans('', '', string.punctuation)
    text = text.translate(translator).lower()

    # Split the text into words
    words = text.split()

    # Count the frequency of each word
    for word in words:
        bag_of_words[word] += 1

    return dict(bag_of_words)


def get_featrues(dataframe):
    # Copy the input DataFrame to avoid modifying the original
    result_df = dataframe.copy()

    # Add columns for TTR, Average Sentence Length, POS Tags, and Bag of Words
    result_df['TTR'] = dataframe['Text'].apply(calculate_ttr)
    result_df['Average_Sentence_Length'] = dataframe['Text'].apply(calculate_average_sentence_length)
    result_df['POS_Tags'] = dataframe['Text'].apply(get_pos_tags)
    result_df['POS_Tag_Counts'] = dataframe['Text'].apply(get_pos_tag_counts)
    result_df['Bag_of_Words'] = dataframe['Text'].apply(create_bag_of_words)

    return result_df[['ID','TTR','Average_Sentence_Length','POS_Tags','POS_Tag_Counts','Bag_of_Words']]

# %%
id_text_df = df[['ID', 'Text']].head(20)

result_dataframe = get_featrues(id_text_df)

# %%
result_dataframe
# Out:
#                 ID       TTR  Average_Sentence_Length  \
# 0   20100531100002  0.911765                10.250000
# 1   20100531100026  1.000000                 6.000000
# 2   20100531100055  0.462939                27.000000
# 3   20100531100625  0.833333                 7.333333
# 4   20100531100634  0.546012                17.727273
# 5   20100531100725  1.000000                 2.000000
# 6   20100531100728  0.627737                31.800000
# 7   20100531100825  1.000000                 2.500000
# 8   20100531100828  0.556757                21.700000
# 9   20100531100924  1.000000                 2.000000
# 10  20100531100926  0.795455                17.000000
# 11  20100531100953  1.000000                 4.500000
# 12  20100531101000  0.619632                12.733333
# 13  20100531101047  1.000000                 2.000000
# 14  20100531101049  0.641791                26.666667
# 15  20100531101123  1.000000                 2.500000
# 16  20100531101126  0.563758                25.571429
# 17  20100531101213  1.000000                 2.000000
# 18  20100531101215  0.680000                27.666667
# 19  20100531101249  1.000000                 8.000000
#
#                                              POS_Tags  \
# 0   [(Mødet, NOUN), (er, AUX), (åbnet, VERB), (., ...
# 1   [(Forhandlingen, NOUN), (er, AUX), (åbnet, VER...
# 2   [(Regeringen, NOUN), (har, AUX), (sammen, ADV)...
# 3   [(Det, PRON), (tror, VERB), (jeg, PRON), (best...
# 4   [(Tak, NOUN), (,, PUNCT), (hr., NOUN), (forman...
# 5                    [(Ordføreren, NOUN), (., PUNCT)]
# 6   [(Som, ADP), (jeg, PRON), (nævnte, VERB), (,, ...
# 7   [(Hr., PROPN), (Torben, PROPN), (Hansen, PROPN...
# 8   [(Tak, NOUN), (,, PUNCT), (hr., NOUN), (forman...
# 9                    [(Ordføreren, NOUN), (., PUNCT)]
# 10  [(Jamen, CCONJ), (jeg, PRON), (har, AUX), (såd...
# 11  [(Hr., PROPN), (Anders, PROPN), (Samuelsen, PR...
# 12  [(Tak, NOUN), (for, ADP), (det, PRON), (., PUN...
# 13                   [(Ordføreren, NOUN), (., PUNCT)]
# 14  [(Jeg, PRON), (mener, VERB), (faktisk, ADV), (...
# 15  [(Hr., PROPN), (Anders, PROPN), (Samuelsen, PR...
# 16  [(Når, SCONJ), (jeg, PRON), (tager, VERB), (fa...
# 17                   [(Ordføreren, NOUN), (., PUNCT)]
# 18  [(Som, ADP), (hr., PROPN), (Anders, PROPN), (S...
# 19  [(Fru, PROPN), (Line, PROPN), (Barfod, PROPN),...
#
#                                        POS_Tag_Counts  \
# 0   {'NOUN': 12, 'AUX': 3, 'VERB': 4, 'PUNCT': 6, ...
# 1   {'NOUN': 3, 'AUX': 1, 'VERB': 1, 'PUNCT': 2, '...
# 2   {'NOUN': 162, 'AUX': 42, 'ADV': 81, 'ADP': 115...
# 3   {'PRON': 3, 'VERB': 3, 'ADV': 4, 'PUNCT': 3, '...
# 4   {'NOUN': 29, 'PUNCT': 27, 'PRON': 19, 'AUX': 1...
# 5                             {'NOUN': 1, 'PUNCT': 1}
# 6   {'ADP': 16, 'PRON': 19, 'VERB': 22, 'PUNCT': 2...
# 7                            {'PROPN': 3, 'PUNCT': 1}
# 8   {'NOUN': 28, 'PUNCT': 30, 'CCONJ': 10, 'PRON':...
# 9                             {'NOUN': 1, 'PUNCT': 1}
# 10  {'CCONJ': 4, 'PRON': 5, 'AUX': 3, 'ADV': 5, 'V...
# 11  {'PROPN': 3, 'ADP': 1, 'DET': 1, 'ADJ': 1, 'NO...
# 12  {'NOUN': 29, 'ADP': 17, 'PRON': 17, 'PUNCT': 2...
# 13                            {'NOUN': 1, 'PUNCT': 1}
# 14  {'PRON': 8, 'VERB': 11, 'ADV': 5, 'PUNCT': 13,...
# 15                           {'PROPN': 3, 'PUNCT': 1}
# 16  {'SCONJ': 15, 'PRON': 23, 'VERB': 24, 'ADV': 1...
# 17                            {'NOUN': 1, 'PUNCT': 1}
# 18  {'ADP': 12, 'PROPN': 3, 'ADV': 7, 'AUX': 6, 'A...
# 19  {'PROPN': 3, 'ADP': 1, 'DET': 1, 'ADJ': 1, 'NO...
#
#                                          Bag_of_Words
# 0   {'mødet': 1, 'er': 1, 'åbnet': 1, 'finansudval...
# 1   {'forhandlingen': 1, 'er': 1, 'åbnet': 1, 'fru...
# 2   {'regeringen': 3, 'har': 6, 'sammen': 2, 'med'...
# 3   {'det': 2, 'tror': 1, 'jeg': 1, 'bestemt': 1, ...
# 4   {'tak': 1, 'hr': 1, 'formand': 1, 'det': 9, 's...
# 5                                   {'ordføreren': 1}
# 6   {'som': 3, 'jeg': 2, 'nævnte': 1, 'er': 3, 're...
# 7                 {'hr': 1, 'torben': 1, 'hansen': 1}
# 8   {'tak': 1, 'hr': 1, 'formand': 1, 'jamen': 1, ...
# 9                                   {'ordføreren': 1}
# 10  {'jamen': 1, 'jeg': 1, 'har': 1, 'sådan': 2, '...
# 11  {'hr': 1, 'anders': 1, 'samuelsen': 1, 'for': ...
# 12  {'tak': 1, 'for': 3, 'det': 10, 'først': 1, 'o...
# 13                                  {'ordføreren': 1}
# 14  {'jeg': 3, 'mener': 1, 'faktisk': 2, 'at': 5, ...
# 15             {'hr': 1, 'anders': 1, 'samuelsen': 1}
# 16  {'når': 3, 'jeg': 1, 'tager': 1, 'fat': 1, 'i'...
# 17                                  {'ordføreren': 1}
# 18  {'som': 2, 'hr': 1, 'anders': 1, 'samuelsen': ...
# 19  {'fru': 1, 'line': 1, 'barfod': 1, 'for': 1, '...

# %% [markdown]
# # Question 2
# # TF-IDF. Segment = speech
# 2. nøgleord som bliver aktualiseret i debatterne om indvandre.
#
#
# Question: Which key words are essential for each party in the debates about immigrants.
#
# Method:
# 1. Use **Tf-Idf** to identify essential key words in speeches on the subject of "Immigration".
# 2. Use group by to group the keywords of each party
# 3. Count keyword for each the party

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import re

from sklearn.feature_extraction.text import TfidfVectorizer

def top_distinctive_words(documents):
    
    with open('dk.txt', 'r', encoding='utf-8-sig') as f:
        stop_words = f.read().split('\n')
    
    # Create a TF-IDF vectorizer
    tfidf_vectorizer = TfidfVectorizer(max_features=10000, stop_words=stop_words)

    # Fit and transform the input documents
    tfidf_matrix = tfidf_vectorizer.fit_transform(documents)

    # Get the feature names (words)
    feature_names = tfidf_vectorizer.get_feature_names_out()

    # Initialize a list to store the top distinctive words for each document
    top_words_list = []

    # Iterate through the TF-IDF matrices for each document
    for tfidf_vector in tfidf_matrix.toarray():
        # Create a list of tuples (word, TF-IDF score) for the current document
        word_tfidf_tuples = [(feature, tfidf_score) for feature, \
                             tfidf_score in zip(feature_names, tfidf_vector) \
                             if tfidf_score > 0]

        # Sort the tuples by TF-IDF score in descending order
        word_tfidf_tuples.sort(key=lambda x: x[1], reverse=True)

        # Select the top five words with the highest TF-IDF scores
        top_words = [word for word, _ in word_tfidf_tuples[:5]]

        top_words_list.append(top_words)

    return top_words_list

# %%
# Subset data
input_data = df[df['samling'] == 20151]
input_data = input_data[input_data['Subject 1'] == 'Immigration']
input_data = input_data[input_data['Role'] == 'medlem'].reset_index(drop=True)

# Create a function to apply top_distinctive_words to each group
def apply_top_distinctive_words(group):
    return top_distinctive_words(group['Text'].tolist())

# Group the DataFrame by 'Party', apply the function, and send the result to a dataframe
top_keywords_by_party = input_data.groupby('Party').apply(apply_top_distinctive_words)\
            .to_frame().reset_index().rename(columns = {0:'key_words'})

# %%
# I got a column called 'key_words'. It is a list of lists. 
# I want to change it into a string to be able to count the keywords in it.
# So I flatten the list and joins it to a text string.

def flatten_list_output_string(list_input):
    return ' '.join([i for y in list_input for i in y])

# Change list og lists to text string
top_keywords_by_party['key_words'] = top_keywords_by_party['key_words'].apply(lambda x : flatten_list_output_string(x))

# %%
import collections
def count_and_sort_words(text):
    # Tokenize the input text into words (split by whitespace and remove punctuation)
    words = text.lower().split()
    
    # Count the occurrences of each word using Counter
    word_counts =collections.Counter(words)

    # Convert the Counter object to a dictionary
    word_counts_dict = dict(word_counts)

    # Sort the dictionary by values (word counts) in descending order
    sorted_word_counts = dict(sorted(word_counts_dict.items(), key=lambda item: item[1], reverse=True))

    return sorted_word_counts

# Aplly the function on the  
top_keywords_by_party['key_words_count'] = top_keywords_by_party['key_words'].apply( lambda x : count_and_sort_words(x)) 
top_keywords_by_party
# Out:
#   Party                                          key_words  \
# 0   ALT  kommunerne investere økonomisk kommunernes udg...
# 1    DF  angående regeringen hjemsendelsesstrategi regn...
# 2    EL  kommunerne maj skrotte kommunernes kommuneafta...
# 3    KF  kommunerne flygtningene penge sikre efterkomme...
# 4    LA  kommunerne danmark større enhedslisten flygtni...
# 5    RV  kommunerne flygtningene formår staten sigt for...
# 6     S  forelægge handlingsplan informations omgående ...
# 7    SF  højskolerne gribe købet oven skub forælder int...
# 8     V  kommunerne kl fleksibelt asylansøgere lettere ...
#
#                                      key_words_count
# 0  {'asyl': 12, 'dansk': 11, 'aftale': 9, 'statsb...
# 1  {'statsborgerskab': 27, 'enhedslisten': 21, 't...
# 2  {'tyrkiet': 22, 'kommunerne': 20, 'arbejdskraf...
# 3  {'statsborgerskab': 8, 'kommunerne': 5, 'folk'...
# 4  {'danmark': 11, '000': 9, 'tyrkiet': 8, 'aftal...
# 5  {'kommunerne': 13, 'flygtninge': 10, 'socialde...
# 6  {'kommunerne': 13, 'dansk': 12, '000': 12, 'fo...
# 7  {'boliger': 9, 'måneder': 8, 'dansk': 7, 'menn...
# 8  {'kommunerne': 14, 'lande': 14, 'danmark': 13,...

# %%
top_keywords_by_party.at[0, 'key_words_count']
# Out:
# {'asyl': 12,
#  'dansk': 11,
#  'aftale': 9,
#  'statsborgerskab': 9,
#  'penge': 9,
#  'værdier': 9,
#  'vores': 8,
#  'danmark': 8,
#  'rigtig': 7,
#  'mennesker': 7,
#  'søge': 7,
#  'samfund': 7,
#  'kommunerne': 6,
#  'børn': 6,
#  'ja': 6,
#  'nærområderne': 6,
#  'lovforslag': 6,
#  'danske': 6,
#  'flygtninge': 6,
#  'tyrkiet': 6,
#  'arbejde': 5,
#  'eu': 5,
#  'arbejdskraft': 4,
#  'år': 4,
#  'virkelig': 4,
#  'lov': 4,
#  'dispensation': 4,
#  'ret': 4,
#  'advokatsamfundet': 4,
#  'verden': 4,
#  'født': 4,
#  'virksomheder': 4,
#  'studerende': 4,
#  'ressourcer': 4,
#  'lovforslaget': 3,
#  'integrerbare': 3,
#  'socialdemokraterne': 3,
#  'integrerbart': 3,
#  'barn': 3,
#  'ordning': 3,
#  'job': 3,
#  'greencardordningen': 3,
#  'væk': 3,
#  'krav': 3,
#  'nye': 3,
#  'udvalget': 3,
#  'ønsker': 3,
#  'handler': 3,
#  'land': 3,
#  'rigtige': 3,
#  'forskel': 3,
#  'vej': 3,
#  'identitet': 3,
#  'svar': 3,
#  'asylansøgere': 3,
#  'spørgsmål': 3,
#  'simpelt': 3,
#  'egentlig': 3,
#  'sikre': 3,
#  'problemet': 3,
#  'dsb': 3,
#  'grænsen': 3,
#  'vende': 3,
#  'flygtning': 3,
#  'hjælpe': 3,
#  'smykker': 3,
#  'syrien': 3,
#  'alliance': 3,
#  'folk': 3,
#  '20': 3,
#  'mulighed': 3,
#  'løsninger': 3,
#  'forrest': 3,
#  'betale': 3,
#  'arbejdsmarkedet': 3,
#  'integrationsydelsen': 3,
#  'kultur': 3,
#  'skabe': 3,
#  'pres': 3,
#  'oplysninger': 3,
#  'bygger': 3,
#  'holdninger': 3,
#  'ordningen': 3,
#  'dumping': 3,
#  'investere': 2,
#  'udgifter': 2,
#  'sigt': 2,
#  'flytte': 2,
#  'beskæftigelse': 2,
#  'kommuner': 2,
#  'enkelte': 2,
#  'højskolerne': 2,
#  'venstre': 2,
#  'landet': 2,
#  'fint': 2,
#  'hæftede': 2,
#  'procesrisiko': 2,
#  'menneskerettighederne': 2,
#  'udlændinge': 2,
#  'flertal': 2,
#  'evner': 2,
#  'princip': 2,
#  'bevare': 2,
#  'kvalificeret': 2,
#  'international': 2,
#  'virksomhederne': 2,
#  'støtter': 2,
#  'udenlandsk': 2,
#  'barnet': 2,
#  'høre': 2,
#  'fuldstændig': 2,
#  'forhold': 2,
#  'højskole': 2,
#  'ændringsforslag': 2,
#  'stillet': 2,
#  'erhvervsrettede': 2,
#  'ordet': 2,
#  'visum': 2,
#  'byrder': 2,
#  'parallelsamfund': 2,
#  'speciallægeerklæring': 2,
#  'forstår': 2,
#  'mand': 2,
#  'indfødsretsudvalget': 2,
#  'søger': 2,
#  'stå': 2,
#  'lægeerklæring': 2,
#  'købt': 2,
#  'håndteres': 2,
#  'håndtere': 2,
#  'internationale': 2,
#  'retning': 2,
#  'skridt': 2,
#  'omfattet': 2,
#  'former': 2,
#  'fastlægge': 2,
#  'tilbageholde': 2,
#  'gået': 2,
#  'sverige': 2,
#  'fingeraftryk': 2,
#  'forestiller': 2,
#  'frihedsberøve': 2,
#  'prøver': 2,
#  'stået': 2,
#  'forpligtelser': 2,
#  'mistillid': 2,
#  'dommerkendelse': 2,
#  'spændt': 2,
#  'tillid': 2,
#  'yderligere': 2,
#  'følelsen': 2,
#  'socialdemokratiets': 2,
#  'uddannet': 2,
#  'opvokset': 2,
#  'fremme': 2,
#  'private': 2,
#  'tilkalde': 2,
#  'tjekke': 2,
#  'ordførerens': 2,
#  'parti': 2,
#  'svært': 2,
#  'folketinget': 2,
#  'følge': 2,
#  'indgår': 2,
#  'ansvar': 2,
#  'myndigheder': 2,
#  'toget': 2,
#  'lyttet': 2,
#  'holdning': 2,
#  'svare': 2,
#  'grænser': 2,
#  'transportørerne': 2,
#  'venstres': 2,
#  'bo': 2,
#  'asylcentre': 2,
#  'pensionsopsparing': 2,
#  'sammenligne': 2,
#  'familiesammenføring': 2,
#  'liberal': 2,
#  'kr': 2,
#  'politik': 2,
#  'faktisk': 2,
#  'lejre': 2,
#  'unhcr': 2,
#  'opmærksom': 2,
#  'sammenhængskraft': 2,
#  'sammenhængskraften': 2,
#  'løse': 2,
#  'erkende': 2,
#  'regning': 2,
#  'attraktivt': 2,
#  'væsentligt': 2,
#  'bedst': 2,
#  'føler': 2,
#  'danskere': 2,
#  'incitament': 2,
#  'formodning': 2,
#  'sag': 2,
#  'grund': 2,
#  'tale': 2,
#  'aftalen': 2,
#  'grimhøjmoskeen': 2,
#  'samfundet': 2,
#  'nej': 2,
#  'indvandring': 2,
#  'målgruppen': 2,
#  'stille': 2,
#  'humanitær': 2,
#  'interessant': 2,
#  'christian': 2,
#  'langballe': 2,
#  'skyld': 2,
#  'gode': 2,
#  'statsløse': 2,
#  'kandidat': 2,
#  'kvoter': 2,
#  'redskab': 2,
#  'kender': 2,
#  'ordentlig': 2,
#  'afstand': 2,
#  'ministerens': 2,
#  'alternativet': 2,
#  'social': 2,
#  'overenskomstmæssige': 2,
#  'løn': 2,
#  'problem': 2,
#  'km': 2,
#  'nævnet': 2,
#  'massivt': 2,
#  'vedkommende': 2,
#  'økonomisk': 1,
#  'kommunernes': 1,
#  'fordelagtigt': 1,
#  'hensyntagen': 1,
#  'screening': 1,
#  'flytter': 1,
#  'undrer': 1,
#  'feriegodtgørelsen': 1,
#  'sammenblanding': 1,
#  'dejlig': 1,
#  'hedder': 1,
#  'sikker': 1,
#  'dømt': 1,
#  'hastelovgivning': 1,
#  'radioen': 1,
#  'spekuleret': 1,
#  'tolke': 1,
#  'stramme': 1,
#  'beklager': 1,
#  'delt': 1,
#  'fejlcitat': 1,
#  'kritisabelt': 1,
#  'årigt': 1,
#  'skilles': 1,
#  'vandene': 1,
#  'kant': 1,
#  'p1': 1,
#  'fremsætte': 1,
#  'uenighed': 1,
#  'forkert': 1,
#  'bangladesh': 1,
#  'ingeniør': 1,
#  'mister': 1,
#  'veluddannet': 1,
#  'acceptabelt': 1,
#  'fuld': 1,
#  'misbrug': 1,
#  'afskære': 1,
#  'skiller': 1,
#  'finn': 1,
#  'frit': 1,
#  'konkludere': 1,
#  'sørensen': 1,
#  'dræner': 1,
#  'relevant': 1,
#  'tydeligere': 1,
#  'herop': 1,
#  'slå': 1,
#  'årrække': 1,
#  'uddannelse': 1,
#  'spørger': 1,
#  'stand': 1,
#  'afskaffe': 1,
#  'ferie': 1,
#  'alderen': 1,
#  'alderskrav': 1,
#  'forælder': 1,
#  'spiller': 1,
#  'glad': 1,
#  'vægt': 1,
#  'korrekt': 1,
#  'forælderen': 1,
#  'integrationsvurderingen': 1,
#  'undgå': 1,
#  'vedtaget': 1,
#  '189': 1,
#  'fleksibilitet': 1,
#  'forhandlingerne': 1,
#  'tilrettelægge': 1,
#  'diskuteret': 1,
#  'peges': 1,
#  'understrege': 1,
#  'dan': 1,
#  'fokus': 1,
#  'anerkende': 1,
#  'beskyldt': 1,
#  'erhvervsrettet': 1,
#  'forløb': 1,
#  'står': 1,
#  'tilrettelagt': 1,
#  'tilrettelægges': 1,
#  'hastebehandle': 1,
#  'uendelig': 1,
#  'vælger': 1,
#  'sommerferien': 1,
#  'forudsætning': 1,
#  'omfang': 1,
#  'begavet': 1,
#  'hukommelsesbesvær': 1,
#  'perfekt': 1,
#  'samtaler': 1,
#  'sprogkundskaberne': 1,
#  'pålægger': 1,
#  'præcisere': 1,
#  'bede': 1,
#  'pålægge': 1,
#  'erklæring': 1,
#  'posttraumatisk': 1,
#  'stress': 1,
#  '188': 1,
#  'afskåret': 1,
#  'tusinde': 1,
#  'grundtvig': 1,
#  'integreret': 1,
#  'udøve': 1,
#  'sindelagskontrol': 1,
#  'pet': 1,
#  'ministeriet': 1,
#  'kontoudskrifter': 1,
#  'læge': 1,
#  'alles': 1,
#  'mail': 1,
#  'navngiven': 1,
#  'gentage': 1,
#  'fire': 1,
#  'sager': 1,
#  'fem': 1,
#  'færre': 1,
#  'godtage': 1,
#  'forhandlinger': 1,
#  'pakke': 1,
#  'sagerne': 1,
#  'fælles': 1,
#  'flygtningepolitik': 1,
#  'alene': 1,
#  'realiteterne': 1,
#  '2017': 1,
#  'enhedslisten': 1,
#  'europarådet': 1,
#  'scene': 1,
#  'fulgt': 1,
#  'hernede': 1,
#  'grænseoverskridende': 1,
#  'løses': 1,
#  'asylansøger': 1,
#  'retssikkerheden': 1,
#  'hørte': 1,
#  'soleklart': 1,
#  'svaret': 1,
#  'ordførertalen': 1,
#  'overtager': 1,
#  'udøvende': 1,
#  'interesseret': 1,
#  'overtage': 1,
#  'udbredt': 1,
#  'embedsmænd': 1,
#  'evighed': 1,
#  'flygtnings': 1,
#  'eksempler': 1,
#  '10': 1,
#  'suspendere': 1,
#  'domstolsprøvelse': 1,
#  'knuth': 1,
#  'marcus': 1,
#  'advokatbistand': 1,
#  'flygtningene': 1,
#  'asyltilstrømningen': 1,
#  'rigtigt': 1,
#  'beholde': 1,
#  'tilbageholder': 1,
#  'øgede': 1,
#  'flugt': 1,
#  'midler': 1,
#  'hastebehandling': 1,
#  'ønskede': 1,
#  'situationen': 1,
#  'kaotisk': 1,
#  'modtagecenter': 1,
#  'begive': 1,
#  'tilbød': 1,
#  'vejene': 1,
#  'beskrive': 1,
#  'hindrede': 1,
#  'løs': 1,
#  'oplyse': 1,
#  'forventning': 1,
#  'spørgsmålene': 1,
#  'runde': 1,
#  'trykkede': 1,
#  'bedt': 1,
#  'høringssvar': 1,
#  'baggrund': 1,
#  'indvendinger': 1,
#  'principper': 1,
#  'slække': 1,
#  'retssamfund': 1,
#  'vigtigste': 1,
#  'afstande': 1,
#  'retsprincip': 1,
#  'dommer': 1,
#  '37': 1,
#  'flygtningeindstrømning': 1,
#  'interneret': 1,
#  'ivrig': 1,
#  'insisteret': 1,
#  'tidsramme': 1,
#  'fastsat': 1,
#  'foretrukket': 1,
#  'insistere': 1,
#  'amnesty': 1,
#  'frihedsberøvelsen': 1,
#  'frihedsberøves': 1,
#  'institut': 1,
#  'gentager': 1,
#  'tilsvarende': 1,
#  'socialdemokratiet': 1,
#  'retspraksis': 1,
#  'gentagne': 1,
#  'loven': 1,
#  'beføjelser': 1,
#  'begrænser': 1,
#  'danmarks': 1,
#  'anbefaler': 1,
#  'overensstemmelse': 1,
#  'dommerstand': 1,
#  'myndighederne': 1,
#  'virkeligheden': 1,
#  'forlænge': 1,
#  'hænger': 1,
#  'grænse': 1,
#  'lukket': 1,
#  'sveriges': 1,
#  'venter': 1,
#  'fastslået': 1,
#  'nødvendigt': 1,
#  'rationalet': 1,
#  'ubestemt': 1,
#  'stemmer': 1,
#  'adresse': 1,
#  'navn': 1,
#  'opgive': 1,
#  'tvangstilbageholde': 1,
#  'ondt': 1,
#  '200': 1,
#  'tilfælde': 1,
#  'særlige': 1,
#  'bestemmelsessted': 1,
#  'fantasi': 1,
#  'ro': 1,
#  'tanker': 1,
#  'ét': 1,
#  'fare': 1,
#  'pct': 1,
#  'drenge': 1,
#  'øger': 1,
#  'bragte': 1,
#  'bekræftede': 1,
#  'eksamineres': 1,
#  'belyst': 1,
#  'bistå': 1,
#  'udvalgsbehandlingen': 1,
#  'alvorligt': 1,
#  'politi': 1,
#  'tilstrækkelig': 1,
#  'farligt': 1,
#  'farvand': 1,
#  'frustrerede': 1,
#  'præcis': 1,
#  'afgivet': 1,
#  'bevidst': 1,
#  'lovbehandlende': 1,
#  'indfører': 1,
#  'transportørkravet': 1,
#  'uddybe': 1,
#  'forstod': 1,
#  'gætter': 1,
#  'lovbehandling': 1,
#  'radikales': 1,
#  'solnedgangsklausul': 1,
#  'beboelsesrum': 1,
#  'enlige': 1,
#  'midlertidighed': 1,
#  'støj': 1,
#  'kravene': 1,
#  'unge': 1,
#  'formuleringen': 1,
#  'gengive': 1,
#  'overbevisning': 1,
#  'behandler': 1,
#  'retsstilling': 1,
#  'sanktionsmuligheder': 1,
#  'billet': 1,
#  'identitetspapirer': 1,
#  'udsteder': 1,
#  'personale': 1,
#  'tyske': 1,
#  'tysk': 1,
#  'selskaber': 1,
#  'uro': 1,
#  'entydigt': 1,
#  'papirer': 1,
#  'derude': 1,
#  'stemme': 1,
#  'kontrollere': 1,
#  'orden': 1,
#  'fastlagt': 1,
#  'jager': 1,
#  'næste': 1,
#  'sjuske': 1,
#  'løsning': 1,
#  'bus': 1,
#  'løsningerne': 1,
#  'sjusk': 1,
#  'sydfyn': 1,
#  'hurtige': 1,
#  'operatørerne': 1,
#  'problemer': 1,
#  'muligvis': 1,
#  'ændringsforslaget': 1,
#  'tid': 1,
#  'hastebehandlingen': 1,
#  'stadigvæk': 1,
#  'forklaring': 1,
#  'koste': 1,
#  'bekymring': 1,
#  'dkr': 1,
#  'estimeret': 1,
#  'selskabers': 1,
#  'forringer': 1,
#  'konkurrenceevne': 1,
#  'ekstra': 1,
#  'udgift': 1,
#  'vægtskål': 1,
#  'min': 1,
#  'ordfører': 1,
#  'grænserne': 1,
#  'lukke': 1,
#  'bolden': 1,
#  'forhastet': 1,
#  'hu': 1,
#  'europa': 1,
#  'solidarisk': 1,
#  'bord': 1,
#  'medarbejderne': 1,
#  'vedgår': 1,
#  'åbenlyst': 1,
#  'fly': 1,
#  'padborg': 1,
#  'rejsedokument': 1,
#  'økonomiske': 1,
#  'tab': 1,
#  'myndighedsopgave': 1,
#  'lovligt': 1,
#  'herske': 1,
#  'igangsætter': 1,
#  'besvarelse': 1,
#  'benægte': 1,
#  'daglig': 1,
#  'menneskerettighedskonventionen': 1,
#  'opklaret': 1,
#  'revisionsbestemmelse': 1,
#  'gennemarbejdet': 1,
#  'handle': 1,
#  'bearbejdet': 1,
#  'hindring': 1,
#  'hovedbanegård': 1,
#  'juleindkøbene': 1,
#  'fragtet': 1,
#  'lastbil': 1,
#  'ordførerområde': 1,
#  'påtage': 1,
#  'modtage': 1,
#  'tænke': 1,
#  'bekræftet': 1,
#  'transporteret': 1,
#  'stige': 1,
#  'tyskland': 1,
#  'transportøransvar': 1,
#  'foregå': 1,
#  'illegale': 1,
#  'scener': 1,
#  'forfulgt': 1,
#  'problematik': 1,
#  'lufthavn': 1,
#  'rejse': 1,
#  'pas': 1,
#  'nyligt': 1,
#  'dejligt': 1,
#  'forhandlede': 1,
#  'ansattes': 1,
#  'kontraktlige': 1,
#  'fortsat': 1,
#  'medarbejdere': 1,
#  'transportører': 1,
#  'afvise': 1,
#  'problemstilling': 1,
#  'svarede': 1,
#  'togene': 1,
#  'skubbe': 1,
#  'bunden': 1,
#  'opgaver': 1,
#  'plæderet': 1,
#  'rettigheder': 1,
#  'spurgt': 1,
#  'vejledende': 1,
#  'voldsomt': 1,
#  'kommune': 1,
#  'behandlingen': 1,
#  'prioriteringssituation': 1,
#  'forpligtelse': 1,
#  'lettere': 1,
#  'plads': 1,
#  'fjerner': 1,
#  'finansloven': 1,
#  'timer': 1,
#  'sove': 1,
#  'ordentligt': 1,
#  'lovpakke': 1,
#  'natten': 1,
#  'dårlige': 1,
#  'mislykket': 1,
#  'lod': 1,
#  'tilstande': 1,
#  'overførselsindkomst': 1,
#  'liv': 1,
#  'realisere': 1,
#  'gæld': 1,
#  'krone': 1,
#  'humant': 1,
#  'vente': 1,
#  'belastende': 1,
#  'efterlade': 1,
#  'efterfølgende': 1,
#  'begæring': 1,
#  'foråret': 1,
#  'indgive': 1,
#  'eneste': 1,
#  'mio': 1,
#  'bidrag': 1,
#  '50': 1,
#  'millioner': 1,
#  'hjertet': 1,
#  'debatten': 1,
#  'berettiget': 1,
#  'bestemmer': 1,
#  'konventionerne': 1,
#  'overholde': 1,
#  'rent': 1,
#  'afbøde': 1,
#  'modvægt': 1,
#  'skaffe': 1,
#  'traumatiserede': 1,
#  'løbe': 1,
#  'kanten': 1,
#  'overskrider': 1,
#  'tilladt': 1,
#  'modsatte': 1,
#  'høringssvarene': 1,
#  'krig': 1,
#  'indrulleret': 1,
#  'hæren': 1,
#  'konventionsstatus': 1,
#  'krigsområde': 1,
#  'kvinde': 1,
#  'synspunkt': 1,
#  'benyttede': 1,
#  'flygtningen': 1,
#  'lejr': 1,
#  'menneske': 1,
#  'par': 1,
#  'bestemme': 1,
#  'flygtningelejr': 1,
#  'asylansøgerne': 1,
#  'integrationen': 1,
#  'cnn': 1,
#  'uhørt': 1,
#  'stramninger': 1,
#  'sinde': 1,
#  'aldrig': 1,
#  'regeringen': 1,
#  'begrænse': 1,
#  'fempunktsplan': 1,
#  'fremlagt': 1,
#  'fælde': 1,
#  'måderne': 1,
#  'velfærd': 1,
#  'hemmelighed': 1,
#  'rammesætter': 1,
#  'fejlslagen': 1,
#  'rammesætte': 1,
#  'udeomkring': 1,
#  'udmærket': 1,
#  'gælder': 1,
#  'dommersystem': 1,
#  'befordrer': 1,
#  'problemstillingerne': 1,
#  'frygten': 1,
#  'mine': 1,
#  'afskrækker': 1,
#  'børnebørn': 1,
#  'generalisering': 1,
#  'kompetenceafklaret': 1,
#  'matchet': 1,
#  'stribevis': 1,
#  'indvandrere': 1,
#  'bock': 1,
#  'mette': 1,
#  'immigranter': 1,
#  'sesam': 1,
#  'sørge': 1,
#  'spørgeren': 1,
#  'barnsben': 1,
#  'beregne': 1,
#  'velfærdssamfund': 1,
#  'problemstillingen': 1,
#  'heroppefra': 1,
#  'afholde': 1,
#  'stikprøvekontrol': 1,
#  '100': 1,
#  'eventuelle': 1,
#  'krydse': 1,
#  'arbejdede': 1,
#  'artikel': 1,
#  'berlingske': 1,
#  'dejlige': 1,
#  'forgårs': 1,
#  'flygtningestrøm': 1,
#  'opbrud': 1,
#  'flygtningestrømme': 1,
#  'undervejs': 1,
#  'slippe': 1,
#  'billeder': 1,
#  'markant': 1,
#  'interview': 1,
#  'hoved': 1,
#  'læne': 1,
#  'vielsesringe': 1,
#  '1930': 1,
#  'udlandet': 1,
#  'fremadrettet': 1,
#  'budgettere': 1,
#  'industri': 1,
#  'kompetenceafklares': 1,
#  'økonomien': 1,
#  'redegøre': 1,
#  'udfordringen': 1,
#  'hvorledes': 1,
#  'forstå': 1,
#  'kvotefordeling': 1,
#  'rumænien': 1,
#  'regeringspartiet': 1,
#  'vælge': 1,
#  'integrere': 1,
#  'øjne': 1,
#  'positivt': 1,
#  'mission': 1,
#  'ruster': 1,
#  'rustes': 1,
#  'vokser': 1,
#  'afskaffelse': 1,
#  'vokse': 1,
#  'forudsætninger': 1,
#  'klassekammerater': 1,
#  'opfylder': 1,
#  'boet': 1,
#  'fatter': 1,
#  'undrede': 1,
#  'argument': 1,
#  'tilfældighed': 1,
#  'grundloven': 1,
#  'ansøger': 1,
#  'nr': 1,
#  '70': 1,
#  'vilkårligt': 1,
#  'tilfreds': 1,
#  'foretager': 1,
#  'vilkårlighed': 1,
#  'foretages': 1,
#  'ydelse': 1,
#  'omfatter': 1,
#  'su': 1,
#  'boligmarkedet': 1,
#  '900': 1,
#  'berørt': 1,
#  'diskriminere': 1,
#  'henriksen': 1,
#  'hån': 1,
#  'praktik': 1,
#  'mødt': 1,
#  'fejlslagne': 1,
#  'forvitrede': 1,
#  'integrationsproces': 1,
#  'støjberg': 1,
#  'inger': 1,
#  'huse': 1,
#  'lever': 1,
#  'adskilligt': 1,
#  'afhænger': 1,
#  'biler': 1,
#  'bnp': 1,
#  'lavere': 1,
#  'betragtninger': 1,
#  'fornødenheder': 1,
#  'sammenligner': 1,
#  'levestandarder': 1,
#  'levestandard': 1,
#  'fattigdomsydelse': 1,
#  'milde': 1,
#  'sammenlignes': 1,
#  'overførsler': 1,
#  '400': 1,
#  'sociale': 1,
#  'arbejdspladserne': 1,
#  'arbejdskammerater': 1,
#  'tilladte': 1,
#  'praksis': 1,
#  'tilkendegivelse': 1,
#  'automatisk': 1,
#  'kriterier': 1,
#  'lovgivningen': 1,
#  'inddragelse': 1,
#  'vedtagelse': 1,
#  'advarsel': 1,
#  'forudgående': 1,
#  'førstegangstilfælde': 1,
#  'bogførte': 1,
#  'el': 1,
#  'endelige': 1,
#  'formulering': 1,
#  'kf': 1,
#  'nepal': 1,
#  'afgørelse': 1,
#  'akut': 1,
#  'forespørgsel': 1,
#  'bekræfte': 1,
#  'opmærksomme': 1,
#  'betalte': 1,
#  'enkeltsager': 1,
#  'risikeret': 1,
#  'teknikalitet': 1,
#  'meningen': 1,
#  'fremgået': 1,
#  'studerer': 1,
#  'talerne': 1,
#  'ubegrænset': 1,
#  'bevist': 1,
#  'forarbejder': 1,
#  'formoder': 1,
#  'formodes': 1,
#  'arbejdstager': 1,
#  'eurodac': 1,
#  'forordningen': 1,
#  'systemet': 1,
#  'centrale': 1,
#  'radikalisering': 1,
#  'isolation': 1,
#  'kommunalbestyrelsen': 1,
#  'modarbejde': 1,
#  'indsatser': 1,
#  'pengene': 1,
#  'giver': 1,
#  'bulgarien': 1,
#  'grænsekontrol': 1,
#  'budgetter': 1,
#  'formulerede': 1,
#  'overblik': 1,
#  'adfærd': 1,
#  'fornemmede': 1,
#  'egentlige': 1,
#  'forespørgslen': 1,
#  'køber': 1,
#  'kulturbudgetter': 1,
#  'skrue': 1,
#  'mangfoldighed': 1,
#  'forskellighed': 1,
#  'bekostning': 1,
#  'rolle': 1,
#  'handles': 1,
#  'højtsvævende': 1,
#  'domstolenes': 1,
#  'aktivt': 1,
#  'lovgivning': 1,
#  'dømmes': 1,
#  'drikker': 1,
#  'forkyndelser': 1,
#  'strid': 1,
#  'beskære': 1,
#  'ulovligt': 1,
#  'dernæst': 1,
#  'forespørgselsspørgsmål': 1,
#  'københavn': 1,
#  '1970': 1,
#  'størrelse': 1,
#  'taler': 1,
#  'harpsøe': 1,
#  'marlene': 1,
#  'tæsk': 1,
#  'moské': 1,
#  'inkluderende': 1,
#  'lukning': 1,
#  'masser': 1,
#  'selvstændigt': 1,
#  'kvindeundertrykkende': 1,
#  'sløret': 1,
#  'frikadeller': 1,
#  'pragmatisk': 1,
#  'domstolene': 1,
#  'politiet': 1,
#  'dømme': 1,
#  'herindefra': 1,
#  'beskriver': 1,
#  'dømmende': 1,
#  'opløst': 1,
#  'stk': 1,
#  'vældig': 1,
#  'barrierer': 1,
#  'beskæftigelseseffekt': 1,
#  'hurtigere': 1,
#  'gevær': 1,
#  'råber': 1,
#  'europaudvalget': 1,
#  'genoverveje': 1,
#  'udbetaling': 1,
#  'genovervejet': 1,
#  'læner': 1,
#  'nødhjælpsorganisationer': 1,
#  'plus': 1,
#  'samarbejde': 1,
#  'euro': 1,
#  'strategisk': 1,
#  'udbetaler': 1,
#  'blander': 1,
#  'tidligere': 1,
#  'entydig': 1,
#  'lag': 1,
#  'én': 1,
#  'indsats': 1,
#  'inklusionsboliger': 1,
#  'inklusionsboligen': 1,
#  'tilbuddet': 1,
#  'borgeren': 1,
#  'støtte': 1,
#  'livsførelse': 1,
#  'ideologisk': 1,
#  'terrorvirksomhed': 1,
#  'stater': 1,
#  'diskutere': 1,
#  'trosretninger': 1,
#  'trossamfund': 1,
#  'association': 1,
#  'skriver': 1,
#  'fremtid': 1,
#  'glæde': 1,
#  'lære': 1,
#  'evnerne': 1,
#  'halve': 1,
#  'børnene': 1,
#  'belastning': 1,
#  'udsætter': 1,
#  'kræve': 1,
#  'sværere': 1,
#  'sent': 1,
#  'udviklet': 1,
#  'leve': 1,
#  'fulde': 1,
#  'fuldgyldige': 1,
#  'integrationens': 1,
#  'uenigheder': 1,
#  'kommentarer': 1,
#  'venner': 1,
#  'præciseret': 1,
#  'diverse': 1,
#  'dæmme': 1,
#  'koreanere': 1,
#  'hjælp': 1,
#  'besat': 1,
#  'beskyttelsen': 1,
#  'flygter': 1,
#  'udviklingsbistanden': 1,
#  'assad': 1,
#  ...}

# %% [markdown]
# # Question 2
# # TF-IDF. Segment = party week

# %%
Brug TF IDF til at identificere key words
Brug TF til at 
Key words skal komme fra TF IDF.

# %% [markdown]
# # Question 3
#
# Sentiment analyse af taler som indeholder noget om flygtning. Det kan f.eks. være taler, som handler om 'os' og 'dem' - nærlæsning. Bliver der større variation i sentiment-scorerne mere varieret op til et valg? Bliver de mere varieret omkring 2015?
#
# M: Brug sentiment analyse til at identificere forandringer i sentimenter i taler knyttet til emneordet Immigration.
# Definition: "SA is a part of applied computational linguistics and attempts to quantify the emotions" (Kran, E., & Orm, S. (2020)).
#
#
# ### Hvilken sentiment analyse tilgang anvender vi?
#
# På Alexandra Instituttets DaNLP repository, et repository for Natural Language Processing resources for the Danish Language, leverer Alexandra Instituttet et overblik over open sentiment analysis models and dataset for Danish.
#
# Der er følgende modeller:
# 1. AFINN - wordlist model, der returnerer en tal-score, der modsvarer en følelse i et ord. Negativ ( minus ), neutral (0) eller positiv ( plus )
# 2. Sentida - wordlist model, der ligesom ovenfor returnerer en tal-score, der modsvarer en følelse.
# 3. BERT Emotion - BERT model, der returner en beskrivende tekststreng, der modsvarer et semantisk felt, som et ord er indlejret i, f.eks. glæde/sindsro, forventning/interesse, tillid/accept.
# 4. BERT Tone - Bert model, der ligeledes returner en beskrivende tekststreng.
# 5. SpaCy Sentiment - Spacy model, der også returner en tekststreng.
# 6. Senda - Bert model, der også returner en tekststreng.
#
# De to første, AFINN og Sentida, samt den sidste Senda, er ikke en del af danlp projektet og dermed ikke en del af DaNLP Python projektet, som kan anvendes via pip.
#
# Kilde: Alexandra Institute. (2021). Sentiment_analysis.md. https://github.com/alexandrainst/danlp/blob/master/docs/docs/tasks/sentiment_analysis.md
#
#
# I denne opgave vil vi anvende sentiment analyse til at se på variationer i scorerne. Vi kan derfor vælge en af de første to, hvorved vi også vælger ikke at anvende DaNLPs Python pakke. Af de to første wordlist modeller, AFINN og Sentida vælger vi Sentida, fordi modellen er blevet opdateret med ny funktionalitet, og fordi set ud fra Finn Årup Nielsens publicationer siden 2019 har han ikke udgivet nyt omkring sentiment analyse i den periode.
#
# Både AFINN og Sentida er wordlist modeller, der aggregerer en sentiment scores baseret på forekomsten af ord fra ordlisten i en given tekst. Den aggregerede score bliver anvendt som en indikator på, hvor positiv teksten
# er. Der er fire problemer forbundet med denne model:
# 1. modellen tager ikke højde for syntaktiske relation mellem ord.
# 2. modellen ignorerer adverbier, og dermed den betydning adverbierne har i at udtykke grader af noget og holdinger til noget.
# 3. modellen afspejler ikke menneskers måde at opfatte følelser.
# 4. modellen kan ikke håndtere ord der betyder to forskellige ting.
# Udviklerne bag Sentida har fundet inspiration i den engelsk sprogede VADER model og har forsøgt at minimere problemerne ved at indbygge forskellige, simple former for "awareness". For eksempel at forøge score omkring negationer, captital letter og udråbstegn for at give disse elementer i sproget større opmærksomhed.
#
# For example:
#
# _“Maden (+0.3) var god (+2.3), (← x 0.5) men(1.5 x →) serviceringen (+0.3) var elendig (-4.3).” ⇒ 1.3 -6 ⇒ sentiment score: -4.7
#
# “The  food (+0.3)was  good (+2.3),  (←  x  0.5) but(1.5x  →) the  service (+0.3)was horrendous (-4.3).” ⇒ 1.3 -6 ⇒ sentiment score: -4.7_
#
#
# _“Det er så sejt (+3.6)!(← x 1.291)” ⇒ sentiment score: 4.6
#
# “It is so cool (+3.6)!(←x 1.291)”⇒ sentiment score: 4.6_
#
#
# _“DET ERSÅ SEJT (+3.6). (← x 1.733)” ⇒ sentiment score: 6.2
#
# “IT IS SO COOL (+3.6). (← x 1.733)” ⇒ sentiment score: 6.2_
#
#
# (Kran, E., & Orm, S. (2020)).
#
#
#
#
#
#
# Neural networks baserede SA modeller som "aspect-based sentiment analysis" kan tage højde for ord og kontekst og er på den måde mere præcise, men eftersom neurale networds modeller forudsætter store mængder af træningsdata, er de langsomme og upraktiske at benytte (Kran, E., & Orm, S. (2020)).

# %%
# pip install sentida

# %%
from sentida import Sentida
# Define the class:
SV = Sentida()

SV.sentida(
        text = 'Lad der blive fred.',
        output = 'mean',
        normal = False,
        speed = 'normal')
# Out:
# 2.0

# %% [markdown]
# https://github.com/alexandrainst/danlp/blob/master/docs/docs/tasks/sentiment_analysis.md
#
# https://github.com/alexandrainst/danlp/blob/master/docs/docs/frameworks/spacy.md

# %% [markdown]
# # Litteraturliste
#
# Lauridsen, G. A., Dalsgaard, J. A., & Svendsen, L. K. B. (2019). SENTIDA: A New Tool for Sentiment Analysis in Danish. Journal of Language Works - Sprogvidenskabeligt Studentertidsskrift, 4(1), 38–53. Retrieved from https://tidsskrift.dk/lwo/article/view/115711
#
# Kran, E., & Orm, S. (2020). EMMA: Danish Natural-Language Processing of Emotion in Text: The new State-of-the-Art in Danish Sentiment Analysis and a Multidimensional Emotional Sentiment Validation Dataset. Journal of Language Works - Sprogvidenskabeligt Studentertidsskrift, 5(1), 92–110. Retrieved from https://tidsskrift.dk/lwo/article/view/121221
#
# Brogaard Pauli, Amalie and Barrett, Maria and Lacroix, Ophélie and Hvingelby, Rasmus. (2021) An open-source toolkit for Danish Natural Language Processing. https://ep.liu.se/ecp/178/053/ecp2021178053.pdf
#
# Alexandra Institute. (2021). Sentiment_analysis.md. https://github.com/alexandrainst/danlp/blob/master/docs/docs/tasks/sentiment_analysis.md
#
# Hansen, Dorte Haltrup and Navarretta, Costanza, 2021, The Danish Parliament Corpus 2009 - 2017, v2, w. subject annotation, CLARIN-DK-UCPH Centre Repository, http://hdl.handle.net/20.500.12115/44.
#
# McKinney, Wes. Python for Data Analysis : Data Wrangling with Pandas, NumPy and Jupyter. Third edition. Sebastopol, CA: O’Reilly Media, Inc., 2022

# %%
# bump_chart
# https://altair-viz.github.io/gallery/bump_chart.html
