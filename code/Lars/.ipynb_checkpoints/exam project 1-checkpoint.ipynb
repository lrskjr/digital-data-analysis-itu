# %% [markdown]
# # Exam details
# Written work:
#
# You will have to analyze a dataset and test a relevant hypothesis.
#
# You should choose your own dataset by Lecture 12 (written hand-in already available)
#
# The report will be written as a Jupiter notebook.
#
# Minimal set of analysis:
# 1) Describe your data and visualize some key dimensions.
# 2) Perform at least two analysis (depending on what is appropriate given the data you selected):
# - Does your data contain quantitative values that allow for a hypothesis testing?
#    IF YES: Formulate an hypothesis and test it. Complement the testing with an appropriate visualization.
# - Does your data contain unstructured textual information?
#  IF YES: Perform sentiment analysis on your data and describe and visualize the results.
# - Does your data contain network structures (or a network structure can be extracted)?
#  IF YES: Ask a question about the network structure and answer it.
#
# OBS: Different datasets can be investigated in many different ways. Any combination of the above-described analysis is acceptable as long as you ask 2 questions.
# e.g. Statistical hypothesis testing + network analysis, Sentiment analysis + network analysis , Statistical hypothesis testing + Statistical hypothesis testing.
#
# Groups:  Find your own group (2 ppls - 3 is possible) let the TAs know before Fall break.
#
# Where to find the data:
# The internet is full of data, these are just few starting points:
# Data (digst.dk) - Danish Open Data
# GHO | By theme (who.int) - WHO Open Data
# DataHub  - Many datasets
# Data.gov Home - Data.gov - US Open Data
# Kaggle - All sort of datasets
# Dataset Search (google.com)
# TLC Trip Record Data - TLC (nyc.gov) - TAXI data in NYC
# Industry data and insights | BFI - Movies!
# CDE (cjis.gov) - Crime data from FBI
# Københavns Kommune (opendata.dk) - Open Data from CPH

# %% [markdown]
# Opgaven skal indeholde en eller flere af følgende:
# - Hypothesis testing
# - Sentiment Analyse
# - Network Analysis
#
# Desuden også
# - Interactive Visualization

# %% [markdown]
# # Data
# Datasættet stammer fra "The Danish Parliament Corpus 2009 - 2017, v2, w. subject annotation".
#
# Kilde:
# Hansen, Dorte Haltrup and Navarretta, Costanza, 2021, The Danish Parliament Corpus 2009 - 2017, v2, w. subject annotation, CLARIN-DK-UCPH Centre Repository, http://hdl.handle.net/20.500.12115/44.
#
#
# Datasættet består af transkriptioner af taler i Folketinget fra første samling 2009 til og med først samling 2016 (6/10 2009 – 7/9 2017). Til hver tale er der tilknyttet metadata, dels om medlemmet af folketinget ('Name', 'Gender', 'Party', 'Role', 'Title', 'Birth', 'Age'), dels om talen (Date', 'samling', 'Start time', 'End time', 'Time', 'Agenda item', 'Case no', 'Case type', 'Agenda title', 'Subject 1', 'Subject 2').
#
# Datasættet er struktureret i tsv txt-filer, som er formateret i utf-8. Der er en fil per møde.
#
# Kilde:
# Samme, Readme
#
#
# Til denne opgave har vi samlet tsv filerne i et nyt datasæt, som vi har gemt i en csv fil separeret med pipes. Csv filen er uploadet til sciencedata.dk, hvorfra den kan downloades via url med pandas.read_csv() metoden.
#
#
#
#
#
# # Emnet
# Emnet er indvandredebatten 2009 - 2017
#
# 1. de vigtigste emner over tid - hvordan er indvandredebatten afspejlet der i?
# 2. nøgleord som bliver aktualiseret i debatterne om indvandre. 2.1. Tf-Idf i relation til at identificere nøgleord.
# 3. sentiment analyse på taler som indeholder noget om flygtning. Det kan f.eks. være taler, som handler om 'os' og 'dem' - nærlæsning. Bliver der større variation i sentiment-scorrerne mere varieret op til et valg? Bliver de mere varieret omkring 2015?
# 4. pos -tag f.eks. verber fra forskellige partier, og hvilke adjektiver knytters sig til et begreb.

# %%
import pandas as pd

# %% [markdown]
# Data ligger på sciencedata.dk og deles derfra med download link.

# %%
df = pd.read_csv('https://sciencedata.dk/shared/825e999a5c13fd22d28d4289fa899ba1?download', sep='|')

# %%
df
# Out:
#                     ID        Date  samling Start time  End time  Time  \
# 0       20100531100002  2010-05-31    20091   10:00:02  10:00:26    24
# 1       20100531100026  2010-05-31    20091   10:00:26  10:00:55    29
# 2       20100531100055  2010-05-31    20091   10:00:55  10:06:25   330
# 3       20100531100625  2010-05-31    20091   10:06:25  10:06:34     9
# 4       20100531100634  2010-05-31    20091   10:06:34  10:07:25    51
# ...                ...         ...      ...        ...       ...   ...
# 381077  20161026184211  2016-10-26    20161   18:42:11  18:42:51    40
# 381078  20161026184251  2016-10-26    20161   18:42:51  18:42:52     1
# 381079  20161026184252  2016-10-26    20161   18:42:52  18:43:39    47
# 381080  20161026184339  2016-10-26    20161   18:43:39  18:43:41     2
# 381081  20161026184341  2016-10-26    20161   18:43:41  18:44:03    22
#
#             Agenda item Case no Case type  \
# 0          2010-05-31-0       0        FM
# 1          2010-05-31-1     222         L
# 2          2010-05-31-1     222         L
# 3          2010-05-31-1     222         L
# 4          2010-05-31-1     222         L
# ...                 ...     ...       ...
# 381077  2016-10-26-2-37     111         S
# 381078  2016-10-26-2-37     111         S
# 381079  2016-10-26-2-37     111         S
# 381080  2016-10-26-2-37     111         S
# 381081     2016-10-26-0       0        FM
#
#                                              Agenda title Subject 1 Subject 2  \
# 0                                                 Punkt 0     other      none
# 1       1. behandling af L 222: Om nedsættelse af dagp...    Labour      none
# 2       1. behandling af L 222: Om nedsættelse af dagp...    Labour      none
# 3       1. behandling af L 222: Om nedsættelse af dagp...    Labour      none
# 4       1. behandling af L 222: Om nedsættelse af dagp...    Labour      none
# ...                                                   ...       ...       ...
# 381077  Spm. nr. S 111: Om veteraner der får afslag på...    Labour      none
# 381078  Spm. nr. S 111: Om veteraner der får afslag på...    Labour      none
# 381079  Spm. nr. S 111: Om veteraner der får afslag på...    Labour      none
# 381080  Spm. nr. S 111: Om veteraner der får afslag på...    Labour      none
# 381081                                            Punkt 0     other      none
#
#                          Name  Gender Party      Role  \
# 0           Holger K. Nielsen    Male    SF   formand
# 1           Holger K. Nielsen    Male    SF   formand
# 2                 Ulla Tørnæs  Female     V    medlem
# 3           Holger K. Nielsen    Male    SF   formand
# 4               Torben Hansen    Male     S    medlem
# ...                       ...     ...   ...       ...
# 381077         Jeppe Jakobsen    Male    DF    medlem
# 381078  Henrik Dam Kristensen    Male     S   formand
# 381079  Jørn Neergaard Larsen    Male     V  minister
# 381080  Henrik Dam Kristensen    Male     S   formand
# 381081  Henrik Dam Kristensen    Male     S   formand
#
#                            Title       Birth  Age  \
# 0             Tredje næstformand  1950-04-23   60
# 1             Tredje næstformand  1950-04-23   60
# 2                            nil  1962-09-04   48
# 3             Tredje næstformand  1950-04-23   60
# 4                            nil  1965-09-11   45
# ...                          ...         ...  ...
# 381077                       nil  1988-08-11   28
# 381078        Første næstformand  1957-01-31   59
# 381079  Beskæftigelsesministeren  1949-02-11   67
# 381080        Første næstformand  1957-01-31   59
# 381081        Første næstformand  1957-01-31   59
#
#                                                      Text
# 0       Mødet er åbnet. Finansudvalget har afgivet: Be...
# 1       Forhandlingen er åbnet. Fru Ulla Tørnæs som or...
# 2       Regeringen har sammen med Dansk Folkeparti ind...
# 3       Det tror jeg bestemt der gør. Der er en række ...
# 4       Tak, hr. formand. Det skal ikke være nogen hem...
# ...                                                   ...
# 381077  Jeg vil bare høre, hvem der er øverste myndigh...
# 381078                                        Ministeren.
# 381079  Man kan godt have ptsd, uden at det er udløst ...
# 381080      Spørgsmålet og spørgetiden er hermed sluttet.
# 381081  Der er ikke mere at foretage i dette møde. Fol...
#
# [381082 rows x 20 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Date', 'samling', 'Start time', 'End time', 'Time',
#        'Agenda item', 'Case no', 'Case type', 'Agenda title', 'Subject 1',
#        'Subject 2', 'Name', 'Gender', 'Party', 'Role', 'Title', 'Birth', 'Age',
#        'Text'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID              object
# Date            object
# samling          int64
# Start time      object
# End time        object
# Time             int64
# Agenda item     object
# Case no         object
# Case type       object
# Agenda title    object
# Subject 1       object
# Subject 2       object
# Name            object
# Gender          object
# Party           object
# Role            object
# Title           object
# Birth           object
# Age              int64
# Text            object
# dtype: object

# %%
df['Subject 1'].value_counts()
# Out:
# Subject 1
# Economy                       55523
# Justice                       40046
# other                         37679
# Labour                        35402
# Social Affairs                24679
# Immigration                   24577
# Education                     23097
# Health care                   20463
# Infrastructure                16677
# Foreign Affairs               15169
# Environment                   14217
# Local and regional affairs    11386
# Agriculture                   11060
# Business                      10773
# Energy                         9532
# Culture                        9378
# Housing                        8305
# European Integration           5687
# Defence                        5160
# Territories                    2272
# Name: count, dtype: int64

# %%
# Convert object column to date time 
df['date_st'] = pd.to_datetime(df['Date'])

# %% [markdown]
# # Forskellige funktioner

# %%
import pandas as pd
import re
import nltk
import spacy
from collections import defaultdict
import string


def calculate_ttr(text):
    # Tranform to lower text case  
    text = text.lower()
    
    # Tokenize the input text into words
    words = re.findall(r'\b\S+\b', text)

    # Calculate the total number of tokens (words)
    total_tokens = len(words)

    # Calculate the number of unique types (unique words)
    unique_types = len(set(words))

    # Calculate the TTR (Type-Token Ratio)
    ttr = unique_types / total_tokens

    return ttr



def calculate_average_sentence_length(text):
    # Tokenize the input text into sentences
    sentences = nltk.sent_tokenize(text)

    # Calculate the total number of sentences
    total_sentences = len(sentences)

    # Calculate the total number of words in all sentences
    total_words = sum(len(nltk.word_tokenize(sentence)) for sentence in sentences)

    # Calculate the average sentence length
    if total_sentences > 0:
        average_length = total_words / total_sentences
    else:
        average_length = 0  # To avoid division by zero if there are no sentences

    return average_length


def get_pos_tags(text):
    # Load the spaCy model
    nlp = spacy.load('da_core_news_sm')

    # Process the text with spaCy
    doc = nlp(text)

    # Extract tokens and their POS tags
    pos_tags = [(token.text, token.pos_) for token in doc]

    return pos_tags

def get_pos_tag_counts(text):
    # Load the spaCy model
    nlp = spacy.load('da_core_news_sm')

    # Process the text with spaCy
    doc = nlp(text)

    # Initialize a dictionary to store POS tag counts
    pos_tag_counts = defaultdict(int)

    # Extract and count POS tags
    for token in doc:
        pos_tag_counts[token.pos_] += 1

    return dict(pos_tag_counts)



def create_bag_of_words(text):
    # Initialize a dictionary to store the bag of words
    bag_of_words = defaultdict(int)

    # Remove punctuation and convert text to lowercase
    translator = str.maketrans('', '', string.punctuation)
    text = text.translate(translator).lower()

    # Split the text into words
    words = text.split()

    # Count the frequency of each word
    for word in words:
        bag_of_words[word] += 1

    return dict(bag_of_words)


def analyze_text_dataframe(dataframe):
    # Copy the input DataFrame to avoid modifying the original
    result_df = dataframe.copy()

    # Add columns for TTR, Average Sentence Length, POS Tags, and Bag of Words
    result_df['TTR'] = dataframe['Text'].apply(calculate_ttr)
    result_df['Average_Sentence_Length'] = dataframe['Text'].apply(calculate_average_sentence_length)
    result_df['POS_Tags'] = dataframe['Text'].apply(get_pos_tags)
    result_df['POS_Tag_Counts'] = dataframe['Text'].apply(get_pos_tag_counts)
    result_df['Bag_of_Words'] = dataframe['Text'].apply(create_bag_of_words)

    return result_df[['ID','TTR','Average_Sentence_Length','POS_Tags','POS_Tag_Counts','Bag_of_Words']]

# %%
id_text_df = df[['ID', 'Text']].head(20)

result_dataframe = analyze_text_dataframe(id_text_df)

# %%
result_dataframe
# Out:
#                 ID       TTR  Average_Sentence_Length  \
# 0   20100531100002  0.911765                10.250000
# 1   20100531100026  1.000000                 6.000000
# 2   20100531100055  0.462939                27.000000
# 3   20100531100625  0.833333                 7.333333
# 4   20100531100634  0.546012                17.727273
# 5   20100531100725  1.000000                 2.000000
# 6   20100531100728  0.627737                31.800000
# 7   20100531100825  1.000000                 2.500000
# 8   20100531100828  0.556757                21.700000
# 9   20100531100924  1.000000                 2.000000
# 10  20100531100926  0.795455                17.000000
# 11  20100531100953  1.000000                 4.500000
# 12  20100531101000  0.619632                12.733333
# 13  20100531101047  1.000000                 2.000000
# 14  20100531101049  0.641791                26.666667
# 15  20100531101123  1.000000                 2.500000
# 16  20100531101126  0.563758                25.571429
# 17  20100531101213  1.000000                 2.000000
# 18  20100531101215  0.680000                27.666667
# 19  20100531101249  1.000000                 8.000000
#
#                                              POS_Tags  \
# 0   [(Mødet, NOUN), (er, AUX), (åbnet, VERB), (., ...
# 1   [(Forhandlingen, NOUN), (er, AUX), (åbnet, VER...
# 2   [(Regeringen, NOUN), (har, AUX), (sammen, ADV)...
# 3   [(Det, PRON), (tror, VERB), (jeg, PRON), (best...
# 4   [(Tak, NOUN), (,, PUNCT), (hr., NOUN), (forman...
# 5                    [(Ordføreren, NOUN), (., PUNCT)]
# 6   [(Som, ADP), (jeg, PRON), (nævnte, VERB), (,, ...
# 7   [(Hr., PROPN), (Torben, PROPN), (Hansen, PROPN...
# 8   [(Tak, NOUN), (,, PUNCT), (hr., NOUN), (forman...
# 9                    [(Ordføreren, NOUN), (., PUNCT)]
# 10  [(Jamen, CCONJ), (jeg, PRON), (har, AUX), (såd...
# 11  [(Hr., PROPN), (Anders, PROPN), (Samuelsen, PR...
# 12  [(Tak, NOUN), (for, ADP), (det, PRON), (., PUN...
# 13                   [(Ordføreren, NOUN), (., PUNCT)]
# 14  [(Jeg, PRON), (mener, VERB), (faktisk, ADV), (...
# 15  [(Hr., PROPN), (Anders, PROPN), (Samuelsen, PR...
# 16  [(Når, SCONJ), (jeg, PRON), (tager, VERB), (fa...
# 17                   [(Ordføreren, NOUN), (., PUNCT)]
# 18  [(Som, ADP), (hr., PROPN), (Anders, PROPN), (S...
# 19  [(Fru, PROPN), (Line, PROPN), (Barfod, PROPN),...
#
#                                        POS_Tag_Counts  \
# 0   {'NOUN': 12, 'AUX': 3, 'VERB': 4, 'PUNCT': 6, ...
# 1   {'NOUN': 3, 'AUX': 1, 'VERB': 1, 'PUNCT': 2, '...
# 2   {'NOUN': 162, 'AUX': 42, 'ADV': 81, 'ADP': 115...
# 3   {'PRON': 3, 'VERB': 3, 'ADV': 4, 'PUNCT': 3, '...
# 4   {'NOUN': 29, 'PUNCT': 27, 'PRON': 19, 'AUX': 1...
# 5                             {'NOUN': 1, 'PUNCT': 1}
# 6   {'ADP': 16, 'PRON': 19, 'VERB': 22, 'PUNCT': 2...
# 7                            {'PROPN': 3, 'PUNCT': 1}
# 8   {'NOUN': 28, 'PUNCT': 30, 'CCONJ': 10, 'PRON':...
# 9                             {'NOUN': 1, 'PUNCT': 1}
# 10  {'CCONJ': 4, 'PRON': 5, 'AUX': 3, 'ADV': 5, 'V...
# 11  {'PROPN': 3, 'ADP': 1, 'DET': 1, 'ADJ': 1, 'NO...
# 12  {'NOUN': 29, 'ADP': 17, 'PRON': 17, 'PUNCT': 2...
# 13                            {'NOUN': 1, 'PUNCT': 1}
# 14  {'PRON': 8, 'VERB': 11, 'ADV': 5, 'PUNCT': 13,...
# 15                           {'PROPN': 3, 'PUNCT': 1}
# 16  {'SCONJ': 15, 'PRON': 23, 'VERB': 24, 'ADV': 1...
# 17                            {'NOUN': 1, 'PUNCT': 1}
# 18  {'ADP': 12, 'PROPN': 3, 'ADV': 7, 'AUX': 6, 'A...
# 19  {'PROPN': 3, 'ADP': 1, 'DET': 1, 'ADJ': 1, 'NO...
#
#                                          Bag_of_Words
# 0   {'mødet': 1, 'er': 1, 'åbnet': 1, 'finansudval...
# 1   {'forhandlingen': 1, 'er': 1, 'åbnet': 1, 'fru...
# 2   {'regeringen': 3, 'har': 6, 'sammen': 2, 'med'...
# 3   {'det': 2, 'tror': 1, 'jeg': 1, 'bestemt': 1, ...
# 4   {'tak': 1, 'hr': 1, 'formand': 1, 'det': 9, 's...
# 5                                   {'ordføreren': 1}
# 6   {'som': 3, 'jeg': 2, 'nævnte': 1, 'er': 3, 're...
# 7                 {'hr': 1, 'torben': 1, 'hansen': 1}
# 8   {'tak': 1, 'hr': 1, 'formand': 1, 'jamen': 1, ...
# 9                                   {'ordføreren': 1}
# 10  {'jamen': 1, 'jeg': 1, 'har': 1, 'sådan': 2, '...
# 11  {'hr': 1, 'anders': 1, 'samuelsen': 1, 'for': ...
# 12  {'tak': 1, 'for': 3, 'det': 10, 'først': 1, 'o...
# 13                                  {'ordføreren': 1}
# 14  {'jeg': 3, 'mener': 1, 'faktisk': 2, 'at': 5, ...
# 15             {'hr': 1, 'anders': 1, 'samuelsen': 1}
# 16  {'når': 3, 'jeg': 1, 'tager': 1, 'fat': 1, 'i'...
# 17                                  {'ordføreren': 1}
# 18  {'som': 2, 'hr': 1, 'anders': 1, 'samuelsen': ...
# 19  {'fru': 1, 'line': 1, 'barfod': 1, 'for': 1, '...

# %% [markdown]
# # Question 2
# # TF-IDF. Segment = speech
#
# Question: Which key words are essential for each party in the debates about immigrants.
#
# Method:
# 1. Use **Tf-Idf** to identify essential key words in every speeches on the subject of "Immigration". Below we calculates the mean TF-IDF scores for each word, and selects the top n words with the highest mean TF-IDF scores. A perfect cleaned text input improves the quality of your TF IDF analyses, so the text is pre-processed before entering the tfidf vectorizer.
# 2. Use group by to group the keywords of each party.
# 3. Score the importance of each keyword for each the party
# 4. Extract the twenty most important keywords
# 5. Visualise them

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import re

with open('dk.txt', 'r', encoding='utf-8-sig') as f:
    stop_words = f.read().split('\n')

def get_most_specific_words(df, n=20):

    def clean_text(text):
        # Replace underscores with spaces
        text = text.replace('_', ' ')

        # Remove numbers (digits) and words containing numbers
        text = re.sub(r'\b\d+\b', '', text)  # Remove standalone digits
        text = re.sub(r'\b\w*\d\w*\b', '', text)  # Remove words with digits

        # Use regular expression to find all non-empty words
        words = re.findall(r'\b\S+\b', text)

        # Join the list of words into a single text string
        cleaned_text = ' '.join(words)

        return cleaned_text
    
    df['Text'] = df['Text'].apply( lambda text : clean_text(text) ) 

    
    # Create a TfidfVectorizer
    tfidf_vectorizer = TfidfVectorizer(max_features=10000, stop_words=stop_words)

    # Fit and transform the text data
    tfidf_matrix = tfidf_vectorizer.fit_transform(df['Text'])

    # Get the TF-IDF values as a DataFrame
    tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names_out())

    # Create a DataFrame to store the top words for each ID
    top_words_df = pd.DataFrame(columns=['ID', 'TopWords'])

    # Iterate through each ID
    for unique_id in df['ID'].unique():
        # Filter the DataFrame for the current ID
        current_id_df = tfidf_df[df['ID'] == unique_id]

        # Calculate the mean TF-IDF score for each word
        mean_tfidf_scores = current_id_df.mean() # Hvorfor mean?

        # Sort the words by mean TF-IDF score in descending order
        top_words_scores = mean_tfidf_scores.sort_values(ascending=False).head(n)
        
        # Store words with TF-IDF score higher than zero
        top_words = top_words_scores[top_words_scores.values > 0]
        
        # Create a new DataFrame for the current ID, top words, and topwords and values
        id_top_words_df = pd.DataFrame({'ID': [unique_id], 'TopWords': [' '.join(top_words.index.tolist())], 'Value': [top_words]})

        # Concatenate the current ID's top words with the result DataFrame
        top_words_df = pd.concat([top_words_df, id_top_words_df], ignore_index=True)

    return top_words_df

# %%
# Subset data
input_data = df[df['samling'] == 20151]
input_data = input_data[input_data['Subject 1'] == 'Immigration']
input_data = input_data[input_data['Role'] == 'medlem']
input_data = input_data[['ID', 'Text']].reset_index(drop=True)

# Use the functions
top_words_by_id = get_most_specific_words(input_data)


# Merge on ID the two dataframes "top_words_by_id" and  "df" (columns party, samling, role, and ID)

df1 = df[['ID', 'samling', 'Role', 'Party']]

df2 = pd.merge(df1, top_words_by_id, how='right', on='ID')

# %% [markdown]
# ### Split-apply-combine
#
# Source: McKinney, Wes. Python for Data Analysis : Data Wrangling with Pandas, NumPy and Jupyter. Third edition. Sebastopol, CA: O’Reilly Media, Inc., 2022. 10.1 How to Think About Group Operations.

# %%
# Group by party and join the top words
df2_party_member_topwords = df2.groupby('Party')['TopWords'].apply(' '.join).reset_index()

# %%
import collections

# The function takes a string of extracted keywords and returns the relative frekvens of each keyword 
def count_key_words(text_string):
    word_list = text_string.split()
    # Count the occurrences of each word
    word_counts = collections.Counter(word_list)
    # Convert Counter object to a dictionary
    d = dict(word_counts)
    # sum the values to a total (normalise) 
    d_value_sum = sum(d.values())
    # get relative values by dividing each word_count with the total sum (normalise)
    relative_freq = [round(((val / d_value_sum) * 100), 3) for val in d.values()]
    # Build new dictionary of keys and relative freq
    keys_rel_freq = dict(zip(d.keys(), relative_freq))
    # Sort dictionary by values
    sorted_dict = sorted(keys_rel_freq.items(), key=lambda x: x[1], reverse=True)
    return sorted_dict

# %%
# Aplly the function on the  
df2_party_member_topwords['TopWords_freq'] = df2_party_member_topwords['TopWords'].apply( lambda x : count_key_words(x))

# %%
df2_party_member_topwords['Top_twenty'] = df2_party_member_topwords['TopWords_freq'].apply(lambda x: x[0:20])

# %%
df2_party_member_topwords
# Out:
#   Party                                           TopWords  \
# 0   ALT  kommunerne investere økonomisk succes kora kom...
# 1    DF  angående hjemsendelsesstrategi efterlyser sand...
# 2    EL  kommunerne maj kommuneaftale skrotte kommunern...
# 3    KF  efterkommerne kommunerne sikre fokusere penge ...
# 4    LA  kommunerne større danmark enhedslisten oppebær...
# 5    RV  kommunerne formår flygtningene staten timing s...
# 6     S  udlændingeudvalg informations forelægge omtale...
# 7    SF  højskolerne skub traditioner gribe skabes købe...
# 8     V  fleksibelt kl kommunerne topartsaftalen asylan...
#
#                                        TopWords_freq  \
# 0  [(danmark, 1.163), (alternativet, 0.489), (fly...
# 1  [(danmark, 0.633), (dansk, 0.443), (statsborge...
# 2  [(flygtninge, 0.468), (tyrkiet, 0.4), (børn, 0...
# 3  [(danmark, 0.702), (folk, 0.661), (flygtninge,...
# 4  [(danmark, 0.544), (liberal, 0.495), (alliance...
# 5  [(venstre, 0.821), (danmark, 0.8), (flygtninge...
# 6  [(danmark, 0.468), (dansk, 0.356), (flygtninge...
# 7  [(mennesker, 0.583), (sf, 0.56), (rigtig, 0.49...
# 8  [(danmark, 0.732), (situation, 0.672), (dansk,...
#
#                                           Top_twenty
# 0  [(danmark, 1.163), (alternativet, 0.489), (fly...
# 1  [(danmark, 0.633), (dansk, 0.443), (statsborge...
# 2  [(flygtninge, 0.468), (tyrkiet, 0.4), (børn, 0...
# 3  [(danmark, 0.702), (folk, 0.661), (flygtninge,...
# 4  [(danmark, 0.544), (liberal, 0.495), (alliance...
# 5  [(venstre, 0.821), (danmark, 0.8), (flygtninge...
# 6  [(danmark, 0.468), (dansk, 0.356), (flygtninge...
# 7  [(mennesker, 0.583), (sf, 0.56), (rigtig, 0.49...
# 8  [(danmark, 0.732), (situation, 0.672), (dansk,...

# %%
import altair as alt
vis_data = df2_party_member_topwords[['Party', 'Top_twenty']]
vis_data
# Out:
#   Party                                         Top_twenty
# 0   ALT  [(danmark, 1.163), (alternativet, 0.489), (fly...
# 1    DF  [(danmark, 0.633), (dansk, 0.443), (statsborge...
# 2    EL  [(flygtninge, 0.468), (tyrkiet, 0.4), (børn, 0...
# 3    KF  [(danmark, 0.702), (folk, 0.661), (flygtninge,...
# 4    LA  [(danmark, 0.544), (liberal, 0.495), (alliance...
# 5    RV  [(venstre, 0.821), (danmark, 0.8), (flygtninge...
# 6     S  [(danmark, 0.468), (dansk, 0.356), (flygtninge...
# 7    SF  [(mennesker, 0.583), (sf, 0.56), (rigtig, 0.49...
# 8     V  [(danmark, 0.732), (situation, 0.672), (dansk,...

# %%
for index, row in vis_data.iterrows():
    print (f"Party: {row['Party']}. Keywords are {row['Top_twenty']}")
# Out:
# Party: ALT. Keywords are [('danmark', 1.163), ('alternativet', 0.489), ('flygtninge', 0.489), ('rigtig', 0.472), ('folk', 0.472), ('danske', 0.472), ('år', 0.421), ('vores', 0.421), ('dansk', 0.421), ('mennesker', 0.404), ('samfund', 0.404), ('arbejde', 0.371), ('mulighed', 0.337), ('lovforslag', 0.303), ('asyl', 0.303), ('spørgeren', 0.27), ('land', 0.253), ('forhold', 0.253), ('forstå', 0.253), ('faktisk', 0.253)]
# Party: DF. Keywords are [('danmark', 0.633), ('dansk', 0.443), ('statsborgerskab', 0.415), ('flygtninge', 0.366), ('forhold', 0.331), ('folkeparti', 0.295), ('faktisk', 0.281), ('danske', 0.281), ('folk', 0.274), ('enhedslisten', 0.246), ('ønsker', 0.232), ('spørgsmål', 0.232), ('regeringen', 0.225), ('simpelt', 0.225), ('grænsekontrol', 0.218), ('år', 0.211), ('venstre', 0.211), ('står', 0.204), ('land', 0.197), ('grimhøjmoskeen', 0.197)]
# Party: EL. Keywords are [('flygtninge', 0.468), ('tyrkiet', 0.4), ('børn', 0.39), ('danmark', 0.39), ('mennesker', 0.361), ('dansk', 0.341), ('eu', 0.283), ('lovforslag', 0.283), ('spørgsmål', 0.283), ('danske', 0.263), ('dommer', 0.253), ('enhedslisten', 0.244), ('kommunerne', 0.234), ('folkeparti', 0.224), ('frihedsberøvet', 0.224), ('år', 0.205), ('arbejdskraft', 0.195), ('født', 0.195), ('statsborgerskab', 0.195), ('penge', 0.185)]
# Party: KF. Keywords are [('danmark', 0.702), ('folk', 0.661), ('flygtninge', 0.454), ('statsborgerskab', 0.454), ('samfund', 0.372), ('vores', 0.372), ('faktisk', 0.372), ('syrien', 0.372), ('spørgsmål', 0.33), ('danske', 0.289), ('belal', 0.289), ('khatib', 0.289), ('el', 0.289), ('forholde', 0.289), ('demokratiet', 0.289), ('handler', 0.289), ('forstår', 0.289), ('land', 0.289), ('dag', 0.289), ('asyl', 0.289)]
# Party: LA. Keywords are [('danmark', 0.544), ('liberal', 0.495), ('alliance', 0.495), ('forhold', 0.396), ('flygtninge', 0.346), ('folkeparti', 0.321), ('menneskerettighedskonvention', 0.321), ('hjælpe', 0.321), ('dag', 0.297), ('enhedslisten', 0.272), ('regler', 0.272), ('venstre', 0.272), ('radikale', 0.272), ('år', 0.272), ('europæiske', 0.272), ('nærområderne', 0.272), ('tyrkiet', 0.272), ('aftale', 0.247), ('ændre', 0.247), ('dansk', 0.247)]
# Party: RV. Keywords are [('venstre', 0.821), ('danmark', 0.8), ('flygtninge', 0.78), ('radikale', 0.718), ('mennesker', 0.636), ('dansk', 0.575), ('spørge', 0.513), ('lovforslag', 0.493), ('børn', 0.472), ('kommunerne', 0.452), ('regeringen', 0.411), ('socialdemokraterne', 0.411), ('rigtig', 0.369), ('folketinget', 0.369), ('ønsker', 0.349), ('situation', 0.349), ('parti', 0.328), ('ordførerens', 0.328), ('ordfører', 0.328), ('statsborgerskab', 0.308)]
# Party: S. Keywords are [('danmark', 0.468), ('dansk', 0.356), ('flygtninge', 0.315), ('kommunerne', 0.305), ('vores', 0.285), ('arbejde', 0.285), ('regeringen', 0.275), ('spørgsmål', 0.254), ('folkeparti', 0.254), ('situation', 0.244), ('mennesker', 0.244), ('spørgsmålet', 0.234), ('antallet', 0.214), ('spørgeren', 0.214), ('muligt', 0.203), ('lovforslag', 0.203), ('enhedslisten', 0.193), ('nej', 0.193), ('ja', 0.183), ('står', 0.183)]
# Party: SF. Keywords are [('mennesker', 0.583), ('sf', 0.56), ('rigtig', 0.493), ('danmark', 0.426), ('dansk', 0.403), ('høre', 0.403), ('flygtninge', 0.381), ('faktisk', 0.381), ('boliger', 0.381), ('lovforslag', 0.336), ('kr', 0.336), ('danske', 0.314), ('folk', 0.314), ('spørgsmål', 0.314), ('hørt', 0.291), ('kvotefordeling', 0.291), ('kommunerne', 0.291), ('måneder', 0.269), ('krav', 0.269), ('arbejde', 0.247)]
# Party: V. Keywords are [('danmark', 0.732), ('situation', 0.672), ('dansk', 0.553), ('vores', 0.493), ('venstre', 0.463), ('mennesker', 0.388), ('danske', 0.388), ('tiltag', 0.374), ('flygtninge', 0.359), ('folkeparti', 0.329), ('år', 0.314), ('ønsker', 0.314), ('lande', 0.314), ('arbejdsmarkedet', 0.314), ('forhold', 0.299), ('enhedslisten', 0.284), ('myndigheder', 0.284), ('folk', 0.284), ('eu', 0.269), ('muligt', 0.269)]

# %%
# create DataFrame using data
data = vis_data.at[2, 'Top_twenty']
vis_data = pd.DataFrame(data, columns =['word', 'score'])
alt.Chart(vis_data).mark_bar().encode(
    x='word',
    y='score').interactive()
# Out:
# C:\Users\lakj\AppData\Local\anaconda3\lib\site-packages\altair\utils\core.py:410: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
data
# Out:
# [('flygtninge', 0.468),
#  ('tyrkiet', 0.4),
#  ('børn', 0.39),
#  ('danmark', 0.39),
#  ('mennesker', 0.361),
#  ('dansk', 0.341),
#  ('eu', 0.283),
#  ('lovforslag', 0.283),
#  ('spørgsmål', 0.283),
#  ('danske', 0.263),
#  ('dommer', 0.253),
#  ('enhedslisten', 0.244),
#  ('kommunerne', 0.234),
#  ('folkeparti', 0.224),
#  ('frihedsberøvet', 0.224),
#  ('år', 0.205),
#  ('arbejdskraft', 0.195),
#  ('født', 0.195),
#  ('statsborgerskab', 0.195),
#  ('penge', 0.185)]

# %% [markdown]
# # Question 2
# # TF-IDF. Segment = party week

# %%
Brug TF IDF til at identificere key words
Brug TF til at 
Key words skal komme fra TF IDF.

# %% [markdown]
# # Question 3
#
# Sentiment analyse af taler som indeholder noget om flygtning. Det kan f.eks. være taler, som handler om 'os' og 'dem' - nærlæsning. Bliver der større variation i sentiment-scorerne mere varieret op til et valg? Bliver de mere varieret omkring 2015?
#
# M: Brug sentiment analyse til at identificere forandringer i sentimenter i taler knyttet til emneordet Immigration.
# Definition: "SA is a part of applied computational linguistics and attempts to quantify the emotions" (Kran, E., & Orm, S. (2020)).
#
#
# ### Hvilken sentiment analyse tilgang anvender vi?
#
# På Alexandra Instituttets DaNLP repository, et repository for Natural Language Processing resources for the Danish Language, leverer Alexandra Instituttet et overblik over open sentiment analysis models and dataset for Danish.
#
# Der er følgende modeller:
# 1. AFINN - wordlist model, der returnerer en tal-score, der modsvarer en følelse i et ord. Negativ ( minus ), neutral (0) eller positiv ( plus )
# 2. Sentida - wordlist model, der ligesom ovenfor returnerer en tal-score, der modsvarer en følelse.
# 3. BERT Emotion - BERT model, der returner en beskrivende tekststreng, der modsvarer et semantisk felt, som et ord er indlejret i, f.eks. glæde/sindsro, forventning/interesse, tillid/accept.
# 4. BERT Tone - Bert model, der ligeledes returner en beskrivende tekststreng.
# 5. SpaCy Sentiment - Spacy model, der også returner en tekststreng.
# 6. Senda - Bert model, der også returner en tekststreng.
#
# De to første, AFINN og Sentida, samt den sidste Senda, er ikke en del af danlp projektet og dermed ikke en del af DaNLP Python projektet, som kan anvendes via pip.
#
# Kilde: Alexandra Institute. (2021). Sentiment_analysis.md. https://github.com/alexandrainst/danlp/blob/master/docs/docs/tasks/sentiment_analysis.md
#
#
# I denne opgave vil vi anvende sentiment analyse til at se på variationer i scorerne. Vi kan derfor vælge en af de første to, hvorved vi også vælger ikke at anvende DaNLPs Python pakke. Af de to første wordlist modeller, AFINN og Sentida vælger vi Sentida, fordi modellen er blevet opdateret med ny funktionalitet, og fordi set ud fra Finn Årup Nielsens publicationer siden 2019 har han ikke udgivet nyt omkring sentiment analyse i den periode.
#
# Både AFINN og Sentida er wordlist modeller, der aggregerer en sentiment scores baseret på forekomsten af ord fra ordlisten i en given tekst. Den aggregerede score bliver anvendt som en indikator på, hvor positiv teksten
# er. Der er fire problemer forbundet med denne model:
# 1. modellen tager ikke højde for syntaktiske relation mellem ord.
# 2. modellen ignorerer adverbier, og dermed den betydning adverbierne har i at udtykke grader af noget og holdinger til noget.
# 3. modellen afspejler ikke menneskers måde at opfatte følelser.
# 4. modellen kan ikke håndtere ord der betyder to forskellige ting.
# Udviklerne bag Sentida har fundet inspiration i den engelsk sprogede VADER model og har forsøgt at minimere problemerne ved at indbygge forskellige, simple former for "awareness". For eksempel at forøge score omkring negationer, captital letter og udråbstegn for at give disse elementer i sproget større opmærksomhed.
#
# For example:
#
# _“Maden (+0.3) var god (+2.3), (← x 0.5) men(1.5 x →) serviceringen (+0.3) var elendig (-4.3).” ⇒ 1.3 -6 ⇒ sentiment score: -4.7
#
# “The  food (+0.3)was  good (+2.3),  (←  x  0.5) but(1.5x  →) the  service (+0.3)was horrendous (-4.3).” ⇒ 1.3 -6 ⇒ sentiment score: -4.7_
#
#
# _“Det er så sejt (+3.6)!(← x 1.291)” ⇒ sentiment score: 4.6
#
# “It is so cool (+3.6)!(←x 1.291)”⇒ sentiment score: 4.6_
#
#
# _“DET ERSÅ SEJT (+3.6). (← x 1.733)” ⇒ sentiment score: 6.2
#
# “IT IS SO COOL (+3.6). (← x 1.733)” ⇒ sentiment score: 6.2_
#
#
# (Kran, E., & Orm, S. (2020)).
#
#
#
#
#
#
# Neural networks baserede SA modeller som "aspect-based sentiment analysis" kan tage højde for ord og kontekst og er på den måde mere præcise, men eftersom neurale networds modeller forudsætter store mængder af træningsdata, er de langsomme og upraktiske at benytte (Kran, E., & Orm, S. (2020)).

# %%
# pip install sentida

# %%
from sentida import Sentida
# Define the class:
SV = Sentida()

SV.sentida(
        text = 'Lad der blive fred.',
        output = 'mean',
        normal = False,
        speed = 'normal')
# Out:
# 2.0

# %%
#pip install sentida

# %%
# Out:
# 2.0

# %% [markdown]
# https://github.com/alexandrainst/danlp/blob/master/docs/docs/tasks/sentiment_analysis.md
#
# https://github.com/alexandrainst/danlp/blob/master/docs/docs/frameworks/spacy.md

# %% [markdown]
# # Litteraturliste
#
# Lauridsen, G. A., Dalsgaard, J. A., & Svendsen, L. K. B. (2019). SENTIDA: A New Tool for Sentiment Analysis in Danish. Journal of Language Works - Sprogvidenskabeligt Studentertidsskrift, 4(1), 38–53. Retrieved from https://tidsskrift.dk/lwo/article/view/115711
#
# Kran, E., & Orm, S. (2020). EMMA: Danish Natural-Language Processing of Emotion in Text: The new State-of-the-Art in Danish Sentiment Analysis and a Multidimensional Emotional Sentiment Validation Dataset. Journal of Language Works - Sprogvidenskabeligt Studentertidsskrift, 5(1), 92–110. Retrieved from https://tidsskrift.dk/lwo/article/view/121221
#
# Brogaard Pauli, Amalie and Barrett, Maria and Lacroix, Ophélie and Hvingelby, Rasmus. (2021) An open-source toolkit for Danish Natural Language Processing. https://ep.liu.se/ecp/178/053/ecp2021178053.pdf
#
# Alexandra Institute. (2021). Sentiment_analysis.md. https://github.com/alexandrainst/danlp/blob/master/docs/docs/tasks/sentiment_analysis.md
#
#
# Hansen, Dorte Haltrup and Navarretta, Costanza, 2021, The Danish Parliament Corpus 2009 - 2017, v2, w. subject annotation, CLARIN-DK-UCPH Centre Repository, http://hdl.handle.net/20.500.12115/44.

# %%
# bump_chart
# https://altair-viz.github.io/gallery/bump_chart.html
